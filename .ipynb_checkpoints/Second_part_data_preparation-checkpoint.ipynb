# %% [markdown]
# # Prepare data

# %%
import pandas as pd

data_id = pd.read_csv('kaggle_data/data_identification.csv')
emotion = pd.read_csv('kaggle_data/emotion.csv')

# %%
import json

file = open("kaggle_data/tweets_DM.json", 'r', encoding='utf-8')
original_data = []
for line in file.readlines():
    dic = json.loads(line)
    original_data.append(dic)

print(type(original_data[0]))
original_data[0]
# Out:
# <class 'dict'>
# {'_score': 391,
#  '_index': 'hashtag_tweets',
#  '_source': {'tweet': {'hashtags': ['Snapchat'],
#    'tweet_id': '0x376b20',
#    'text': 'People who post "add me on #Snapchat" must be dehydrated. Cuz man.... that\'s <LH>'}},
#  '_crawldate': '2015-05-23 11:42:47',
#  '_type': 'tweets'}

# %%
for item in original_data:
    item.update(item['_source']['tweet'])
    del item['_source']
    
original_data[0]
# Out:
# {'_score': 391,
#  '_index': 'hashtag_tweets',
#  '_crawldate': '2015-05-23 11:42:47',
#  '_type': 'tweets',
#  'hashtags': ['Snapchat'],
#  'tweet_id': '0x376b20',
#  'text': 'People who post "add me on #Snapchat" must be dehydrated. Cuz man.... that\'s <LH>'}

# %%
original_data = pd.DataFrame(original_data)
original_data
# Out:
#          _score          _index           _crawldate   _type  \
# 0           391  hashtag_tweets  2015-05-23 11:42:47  tweets
# 1           433  hashtag_tweets  2016-01-28 04:52:09  tweets
# 2           232  hashtag_tweets  2017-12-25 04:39:20  tweets
# 3           376  hashtag_tweets  2016-01-24 23:53:05  tweets
# 4           989  hashtag_tweets  2016-01-08 17:18:59  tweets
# ...         ...             ...                  ...     ...
# 1867530     827  hashtag_tweets  2015-05-12 12:51:52  tweets
# 1867531     368  hashtag_tweets  2017-10-02 17:54:04  tweets
# 1867532     498  hashtag_tweets  2016-10-10 11:04:32  tweets
# 1867533     840  hashtag_tweets  2016-09-02 14:25:06  tweets
# 1867534     360  hashtag_tweets  2016-11-16 01:40:07  tweets
#
#                                 hashtags  tweet_id  \
# 0                             [Snapchat]  0x376b20
# 1          [freepress, TrumpLegacy, CNN]  0x2d5350
# 2                           [bibleverse]  0x28b412
# ...

# %% [markdown]
# # Data analysis and preprocess

# %% [markdown]
# ## merge dataframe and delete irrelevent feature

# %%
data = original_data.copy()
data
# Out:
#          _score          _index           _crawldate   _type  \
# 0           391  hashtag_tweets  2015-05-23 11:42:47  tweets
# 1           433  hashtag_tweets  2016-01-28 04:52:09  tweets
# 2           232  hashtag_tweets  2017-12-25 04:39:20  tweets
# 3           376  hashtag_tweets  2016-01-24 23:53:05  tweets
# 4           989  hashtag_tweets  2016-01-08 17:18:59  tweets
# ...         ...             ...                  ...     ...
# 1867530     827  hashtag_tweets  2015-05-12 12:51:52  tweets
# 1867531     368  hashtag_tweets  2017-10-02 17:54:04  tweets
# 1867532     498  hashtag_tweets  2016-10-10 11:04:32  tweets
# 1867533     840  hashtag_tweets  2016-09-02 14:25:06  tweets
# 1867534     360  hashtag_tweets  2016-11-16 01:40:07  tweets
#
#                                 hashtags  tweet_id  \
# 0                             [Snapchat]  0x376b20
# 1          [freepress, TrumpLegacy, CNN]  0x2d5350
# 2                           [bibleverse]  0x28b412
# ...

# %%
print(data['_index'].unique())
print(data['_type'].unique())
# Out:
# ['hashtag_tweets']
# ['tweets']

# %%
data.drop('_score', axis=1, inplace=True)
data.drop('_index', axis=1, inplace=True)
data.drop('_crawldate', axis=1, inplace=True)
data.drop('_type', axis=1, inplace=True)
data
# Out:
#                                 hashtags  tweet_id  \
# 0                             [Snapchat]  0x376b20
# 1          [freepress, TrumpLegacy, CNN]  0x2d5350
# 2                           [bibleverse]  0x28b412
# 3                                     []  0x1cd5b0
# 4                                     []  0x2de201
# ...                                  ...       ...
# 1867530  [mixedfeeling, butimTHATperson]  0x316b80
# 1867531                               []  0x29d0cb
# 1867532                               []  0x2a6a4f
# 1867533                               []  0x24faed
# 1867534                    [Sundayvibes]  0x34be8c
#
#                                                       text
# 0        People who post "add me on #Snapchat" must be ...
# 1        @brianklaas As we see, Trump is dangerous to #...
# 2        Confident of your obedience, I write to you, k...
# 3                      Now ISSA is stalking Tasha 😂😂😂 <LH>
# ...

# %%
data_id
# Out:
#          tweet_id identification
# 0        0x28cc61           test
# 1        0x29e452          train
# 2        0x2b3819          train
# 3        0x2db41f           test
# 4        0x2a2acc          train
# ...           ...            ...
# 1867530  0x227e25          train
# 1867531  0x293813          train
# 1867532  0x1e1a7e          train
# 1867533  0x2156a5          train
# 1867534  0x2bb9d2          train
#
# [1867535 rows x 2 columns]

# %%
data = data.merge(data_id, on='tweet_id')
data
# Out:
#                                 hashtags  tweet_id  \
# 0                             [Snapchat]  0x376b20
# 1          [freepress, TrumpLegacy, CNN]  0x2d5350
# 2                           [bibleverse]  0x28b412
# 3                                     []  0x1cd5b0
# 4                                     []  0x2de201
# ...                                  ...       ...
# 1867530  [mixedfeeling, butimTHATperson]  0x316b80
# 1867531                               []  0x29d0cb
# 1867532                               []  0x2a6a4f
# 1867533                               []  0x24faed
# 1867534                    [Sundayvibes]  0x34be8c
#
#                                                       text identification
# 0        People who post "add me on #Snapchat" must be ...          train
# 1        @brianklaas As we see, Trump is dangerous to #...          train
# 2        Confident of your obedience, I write to you, k...           test
# ...

# %%
test_data = data[data['identification'] == 'test']
test_data.to_pickle("kaggle_data/test_data.pkl")
test_data
# Out:
#                                   hashtags  tweet_id  \
# 2                             [bibleverse]  0x28b412
# 4                                       []  0x2de201
# 9        [materialism, money, possessions]  0x218443
# 30                    [GodsPlan, GodsWork]  0x2939d5
# 33                                      []  0x26289a
# ...                                    ...       ...
# 1867525                                 []  0x2913b4
# 1867529                                 []  0x2a980e
# 1867530    [mixedfeeling, butimTHATperson]  0x316b80
# 1867531                                 []  0x29d0cb
# 1867532                                 []  0x2a6a4f
#
#                                                       text identification
# 2        Confident of your obedience, I write to you, k...           test
# 4        "Trust is not the same as faith. A friend is s...           test
# 9        When do you have enough ? When are you satisfi...           test
# ...

# %%
emotion
# Out:
#          tweet_id       emotion
# 0        0x3140b1       sadness
# 1        0x368b73       disgust
# 2        0x296183  anticipation
# 3        0x2bd6e1           joy
# 4        0x2ee1dd  anticipation
# ...           ...           ...
# 1455558  0x38dba0           joy
# 1455559  0x300ea2           joy
# 1455560  0x360b99          fear
# 1455561  0x22eecf           joy
# 1455562  0x2fb282  anticipation
#
# [1455563 rows x 2 columns]

# %%
train_data = data.merge(emotion, on='tweet_id')
train_data.to_pickle("kaggle_data/train_data.pkl")
train_data
# Out:
#                               hashtags  tweet_id  \
# 0                           [Snapchat]  0x376b20
# 1        [freepress, TrumpLegacy, CNN]  0x2d5350
# 2                                   []  0x1cd5b0
# 3            [authentic, LaughOutLoud]  0x1d755c
# 4                                   []  0x2c91a8
# ...                                ...       ...
# 1455558              [NoWonder, Happy]  0x321566
# 1455559                             []  0x38959e
# 1455560                     [blessyou]  0x2cbca6
# 1455561                             []  0x24faed
# 1455562                  [Sundayvibes]  0x34be8c
#
#                                                       text identification  \
# 0        People who post "add me on #Snapchat" must be ...          train
# 1        @brianklaas As we see, Trump is dangerous to #...          train
# 2                      Now ISSA is stalking Tasha 😂😂😂 <LH>          train
# 3        @RISKshow @TheKevinAllison Thx for the BEST TI...          train
# ...
